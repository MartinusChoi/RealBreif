# %% [markdown]
# # 기능 구현 실험

# %% [markdown]
# ## 1. 키워드 선정

# %% [markdown]
# #### 테스트 텍스트

# %%
text = """
당사는 제품의 특성에 따라 DX(Device eXperience), DS(Device Solutions)
2개의 부문과 패널 사업을 영위하는 SDC(삼성디스플레이(주) 및 그 종속기업),
전장부품사업 등을 영위하는 Harman(Harman International Industries, Inc.및 그 종속기업)으로 나누어 경영을 하고 있습니다.

당사는 본사를 거점으로 한국과 DX 부문 산하 해외 9개 지역총괄, DS 부문 산하 해외 5개
지역총괄의 생산ᆞ판매법인 및 SDC, Harman 산하 종속기업 등 228개의 종속기업으로 구성된 글로벌 전자 기업입니다.
 
각 부문별 주요 제품은 다음과 같습니다. 
 
[DX 부문]
 
DX 부문은 TV, 모니터, 냉장고, 세탁기, 에어컨 및 스마트폰, 태블릿, 웨어러블(Wearable)제품, 네트워크시스템 등을 생산ᆞ판매하는 사업으로 구성되어 있습니다.
 
TV사업은 2006년부터 2024년까지 19년 연속 판매 1위를 지키고 있습니다. 업체간 경쟁이 심화되는 가운데, 당사는 초대형 TV를 선두로 하여, 주력제품에 AI신기술을 대폭 적용해 경쟁사들과의 기술격차를 벌리고 있습니다. 
또한, 가전 사업은 친환경·고효율 기술을 통해 제품의 기본 성능의 우위는 물론이고, 변화하는 라이프스타일에 대한 깊은 이해를 바탕으로 소비자의 삶을 편리하게 하는 제품과 서비스를 지속 출시하고 있습니다.
 
모바일사업은 2011년부터 2024년까지 14년 연속 글로벌 출하량 1위를 유지하고 있습니다.
'갤럭시(Galaxy)' 브랜드를 통해 프리미엄부터 보급형까지 다양하고 경쟁력 있는 스마트폰 라인업과 태블릿, 웨어러블, 디지털 월렛 등을 활용하여 시장 상황에 최적화된 제품 포트폴리오를 운영하고 있습니다.
 
[DS 부문]

DS 부문은 DRAM, NAND Flash 등 제품을 생산ᆞ판매하는 메모리 반도체 사업과 모바일
AP, 카메라 센서칩 등을 설계ᆞ판매하는 System LSI 사업, 반도체 제조 위탁 생산을 하는
Foundry 사업 등으로 구성되어 있습니다.
메모리 반도체 사업은 DRAM, NAND Flash 제품 등에 선단 공정 기술을 적용하고,
고부가 솔루션 중심의 사업 포트폴리오 운영을 통해 제품을 차별화하고 원가 경쟁력을 제고하는 등 질적 성장에 주력하여 전 세계 메모리 시장에서 선두 자리를 지속적으로 유지하고 있습니다.
System LSI 사업은 모바일용 반도체 사업에서 차량용 반도체 사업으로 확장을 추진 중이며,
On-Device AI 적용, 고성능 IP 탑재 등 제품의 차별화를 통해 고객과 협력 강화 및 응용처를
다변화하여 시장 지배력을 확대하는 한편, 차세대 기술 개발도 지속 추진하고 있습니다.
Foundry 사업은 Advanced 공정에서 지속적인 기술 경쟁력 강화를 통해 중장기 수요확보에
집중하고 있으며, Mature 공정에서는 응용처를 확대하는 한편 원가 경쟁력을
강화할 예정입니다.
 
[SDC]

SDC의 중소형 디스플레이 패널 사업은 차별화된 기술을 바탕으로 OLED 패널의 점유율을
확대하는 한편 폴더블ᆞIT(태블릿/노트북)ᆞAuto 등 다양한 응용처의 제품 출시를 통해 시장 영역을 넓혀 나가고 있습니다. 
또한, 대형 디스플레이 패널 사업은 고화질, 초대형, 퀀텀닷(Quantum Dot) 등 프리미엄 제품 중심으로 사업을 특화하고,기술 및 생산성 향상을 지속 추진하여 사업 경쟁력을 제고하고 있습니다. 

[Harman]

Harman은 커넥티드카 제품 및 솔루션 등을 개발 및 공급하는 전장부품 사업과 일반 오디오
제품 및 프로페셔널 오디오 솔루션을 제공하는 라이프스타일 오디오 사업을 운영하고 있습니다.
전장부품 시장의 선두업체로서 완성차 업체들에게 경쟁력 있는 제품을 공급하고 있을 뿐 아니라, 
오디오 시장에서도 혁신 제품 판매를 통해 일반 소비자들과 음악 애호가들 사이에서 명성을 쌓아왔습니다.
 
또한, 당사 타 제품군과의 협업 확대를 통해 차별화된 고객 경험을 제공하고 자체 개발 및 전략적 인수 등을 통해 각 사업 분야에서 경쟁력을 강화하고 있습니다.
"""

# %% [markdown]
# ### 1-1. 키워드 추출의 다양한 방법론

# %% [markdown]
# #### 1-1-1. `TF-IDF`
#
# > 텍스트에서 특정 단어(키워드)의 중요도를 계산하는 전통적인 NLP 기법
#
# - 장점
#     - 빠르고, 간단함
#     - 일반적인 주제 파악에 용이함
# - 단점
#     - 빈도만을 기반으로 중요도를 계산하기 때문에 '맥락/의미' 파악에는 한계를 가짐
#     - 복수의 문서를 활용하지 않으면 단순 단어 빈도 점수와 동일하게 작동

# %%
docs = [doc for doc in text.split("\n") if len(doc) > 10]

docs
# Out:
# ['당사는 제품의 특성에 따라 DX(Device eXperience), DS(Device Solutions)',
#  '2개의 부문과 패널 사업을 영위하는 SDC(삼성디스플레이(주) 및 그 종속기업),',
#  '전장부품사업 등을 영위하는 Harman(Harman International Industries, Inc.및 그 종속기업)으로 나누어 경영을 하고 있습니다.',
#  '당사는 본사를 거점으로 한국과 DX 부문 산하 해외 9개 지역총괄, DS 부문 산하 해외 5개',
#  '지역총괄의 생산ᆞ판매법인 및 SDC, Harman 산하 종속기업 등 228개의 종속기업으로 구성된 글로벌 전자 기업입니다.',
#  '각 부문별 주요 제품은 다음과 같습니다. ',
#  'DX 부문은 TV, 모니터, 냉장고, 세탁기, 에어컨 및 스마트폰, 태블릿, 웨어러블(Wearable)제품, 네트워크시스템 등을 생산ᆞ판매하는 사업으로 구성되어 있습니다.',
#  'TV사업은 2006년부터 2024년까지 19년 연속 판매 1위를 지키고 있습니다. 업체간 경쟁이 심화되는 가운데, 당사는 초대형 TV를 선두로 하여, 주력제품에 AI신기술을 대폭 적용해 경쟁사들과의 기술격차를 벌리고 있습니다. ',
#  '또한, 가전 사업은 친환경·고효율 기술을 통해 제품의 기본 성능의 우위는 물론이고, 변화하는 라이프스타일에 대한 깊은 이해를 바탕으로 소비자의 삶을 편리하게 하는 제품과 서비스를 지속 출시하고 있습니다.',
#  '모바일사업은 2011년부터 2024년까지 14년 연속 글로벌 출하량 1위를 유지하고 있습니다.',
#  "'갤럭시(Galaxy)' 브랜드를 통해 프리미엄부터 보급형까지 다양하고 경쟁력 있는 스마트폰 라인업과 태블릿, 웨어러블, 디지털 월렛 등을 활용하여 시장 상황에 최적화된 제품 포트폴리오를 운영하고 있습니다.",
#  'DS 부문은 DRAM, NAND Flash 등 제품을 생산ᆞ판매하는 메모리 반도체 사업과 모바일',
#  'AP, 카메라 센서칩 등을 설계ᆞ판매하는 System LSI 사업, 반도체 제조 위탁 생산을 하는',
#  'Foundry 사업 등으로 구성되어 있습니다.',
#  '메모리 반도체 사업은 DRAM, NAND Flash 제품 등에 선단 공정 기술을 적용하고,',
#  '고부가 솔루션 중심의 사업 포트폴리오 운영을 통해 제품을 차별화하고 원가 경쟁력을 제고하는 등 질적 성장에 주력하여 전 세계 메모리 시장에서 선두 자리를 지속적으로 유지하고 있습니다.',
#  'System LSI 사업은 모바일용 반도체 사업에서 차량용 반도체 사업으로 확장을 추진 중이며,',
#  'On-Device AI 적용, 고성능 IP 탑재 등 제품의 차별화를 통해 고객과 협력 강화 및 응용처를',
#  '다변화하여 시장 지배력을 확대하는 한편, 차세대 기술 개발도 지속 추진하고 있습니다.',
#  'Foundry 사업은 Advanced 공정에서 지속적인 기술 경쟁력 강화를 통해 중장기 수요확보에',
#  '집중하고 있으며, Mature 공정에서는 응용처를 확대하는 한편 원가 경쟁력을',
#  'SDC의 중소형 디스플레이 패널 사업은 차별화된 기술을 바탕으로 OLED 패널의 점유율을',
#  '확대하는 한편 폴더블ᆞIT(태블릿/노트북)ᆞAuto 등 다양한 응용처의 제품 출시를 통해 시장 영역을 넓혀 나가고 있습니다. ',
#  '또한, 대형 디스플레이 패널 사업은 고화질, 초대형, 퀀텀닷(Quantum Dot) 등 프리미엄 제품 중심으로 사업을 특화하고,기술 및 생산성 향상을 지속 추진하여 사업 경쟁력을 제고하고 있습니다. ',
#  'Harman은 커넥티드카 제품 및 솔루션 등을 개발 및 공급하는 전장부품 사업과 일반 오디오',
#  '제품 및 프로페셔널 오디오 솔루션을 제공하는 라이프스타일 오디오 사업을 운영하고 있습니다.',
#  '전장부품 시장의 선두업체로서 완성차 업체들에게 경쟁력 있는 제품을 공급하고 있을 뿐 아니라, ',
#  '오디오 시장에서도 혁신 제품 판매를 통해 일반 소비자들과 음악 애호가들 사이에서 명성을 쌓아왔습니다.',
#  '또한, 당사 타 제품군과의 협업 확대를 통해 차별화된 고객 경험을 제공하고 자체 개발 및 전략적 인수 등을 통해 각 사업 분야에서 경쟁력을 강화하고 있습니다.']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(docs)

# '단어(키워드)'의 목록 반환
feature_names = vectorizer.get_feature_names_out()

# 계산된 tf-idf 점수 반환
dense = tfidf_matrix.todense()

# 단어 별 tf-idf 매트릭스를 dataframe 화
tfidf_df = pd.DataFrame(dense, columns=feature_names)

tfidf_df
# Out:
#          14년      19년       1위를  ...      확대하는       확장을      활용하여
# 0   0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 1   0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 2   0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 3   0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 4   0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 5   0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 6   0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 7   0.000000  0.20525  0.182806  ...  0.000000  0.000000  0.000000
# 8   0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 9   0.349383  0.00000  0.311178  ...  0.000000  0.000000  0.000000
# 10  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.226298
# 11  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 12  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 13  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 14  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 15  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 16  0.000000  0.00000  0.000000  ...  0.000000  0.300345  0.000000
# 17  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 18  0.000000  0.00000  0.000000  ...  0.278369  0.000000  0.000000
# 19  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 20  0.000000  0.00000  0.000000  ...  0.297376  0.000000  0.000000
# 21  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 22  0.000000  0.00000  0.000000  ...  0.229268  0.000000  0.000000
# 23  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 24  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 25  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 26  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 27  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
# 28  0.000000  0.00000  0.000000  ...  0.000000  0.000000  0.000000
#
# [29 rows x 279 columns]

# %%
def get_top_keywords(row:pd.Series, top_n=3):
    return row.sort_values(ascending=False).head(top_n).index.tolist()

# %%
keywords_per_doc = tfidf_df.apply(get_top_keywords, axis=1)

print(keywords_per_doc)
# Out:
# 0     [device, solutions, 따라]
# 1          [부문과, 삼성디스플레이, 주]
# 2       [harman, 경영을, 전장부품사업]
# 3                [부문, 해외, 산하]
# 4           [종속기업으로, 구성된, 전자]
# 5             [제품은, 주요, 같습니다]
# 6         [냉장고, 네트워크시스템, 세탁기]
# 7          [주력제품에, 하여, 기술격차를]
# 8            [제품과, 이해를, 출시하고]
# 9         [14년, 출하량, 2011년부터]
# 10       [활용하여, 프리미엄부터, 다양하고]
# 11         [모바일, flash, dram]
# 12         [생산을, 설계ᆞ판매하는, 제조]
# 13       [등으로, 구성되어, foundry]
# 14             [선단, 등에, 적용하고]
# 15            [자리를, 중심의, 운영을]
# 16           [반도체, 모바일용, 중이며]
# 17             [on, 강화, 차별화를]
# 18          [지배력을, 차세대, 추진하고]
# 19     [advanced, 지속적인, 공정에서]
# 20         [공정에서는, 집중하고, 있으며]
# 21          [중소형, oled, sdc의]
# 22            [출시를, 나가고, 다양한]
# 23          [추진하여, dot, 제고하고]
# 24     [harman은, 공급하는, 커넥티드카]
# 25        [오디오, 제공하는, 라이프스타일]
# 26         [시장의, 완성차, 선두업체로서]
# 27           [시장에서도, 혁신, 판매를]
# 28               [통해, 자체, 인수]
# dtype: object

# %% [markdown]
# #### 1-1-2. TextRank
#
# > Google의 PageRank에서 영감을 받은 '그래프 기반 키워드 추출 알고리즘'.
#
# - 장점
#     - 의미적 관계 반영
# - 단점
#     - 계산 비용 큼
#     - 텍스트 품질에 많은 영향을 받음
#
# ##### [처리과정]
#
# 1. 텍스트를 토큰화, 품사 태깅 -> 명사, 형용사 등 의미 있는 단어만 후보 선정
# 2. 그래프 생성
#     - 단어를 노드로, 일정 윈도우 크기 내에서 함께 등장하는 단어 쌍에 엣지 형성
#     - 엣지 가중치 : 단어쌍 공동 출현 빈도
# 3. PageRank 방식 점수 계산
#     - 각 단어 중요도 : 연결된 타 단어(노드)들의 중요도에 의해 반복적 갱신
#     - 연결된 고득점 단어와 자주 연결된 단어일수록 점수 향샹
#     - 이 과정을 점수가 수렴할 때 까지 반복
# 4. 최종 점수 상위 단어 추출 (연속으로 등장하는 경우 합쳐서 구문으로 반환 가능)
#
# > 한국어에 대해 textrank와 유사한 키워드 추출 기능을 제공하는 라이브러리 : `krwordrank`

# %% [markdown]
# ##### 직접 구현

# %%
from konlpy.tag import Okt
import numpy as np
from sklearn.preprocessing import normalize

okt = Okt()

nouns = okt.nouns(text)

stopwords = list(set(["종", "그", "및", "등", "각", "개", "를", "사", "위", "전", "용", "처", "통해", "기술", "부문", "경쟁력", "제품", "사업",
             "시장", "판매", "지속", "기업", "생산", "확대", "기업", "당사", "차별", "솔루션", "부품", "개발", "적용", "공정", "한편", "업체",
             "운영", "선두", "전장", "또한", "추진", "구성", "응용", "일반", "영위", "해외", "경영", "본사", "지역", "주요", "다음", "삼성",
             "협업", "서비스", "선단", "특화", "심화", "제품군", "설계", "대형", "세계", "소비자", "라인업", "혁신", "차세대", "공급", "글로벌", "고화질",
             "경쟁", "강화", "더블", "경험", "율", "의", "고하", "뿐", "로서", "탑재", "자체", "원가"]))

vocab = list(set([noun for noun in nouns if noun not in stopwords]))
vocab_to_idx = {word: idx for idx, word in enumerate(vocab)}
vocab_size = len(vocab)

# 공동 출현 행렬 생성
window = 5
graph = np.zeros((vocab_size, vocab_size))
words = text.split()
for i, word in enumerate(words):
    if word in vocab:
        for j in range(max(i-window, 0), min(i+window+1, len(words))):
            if (i != j) and words[j] in vocab:
                idx1, idx2 = vocab_to_idx[word], vocab_to_idx[words[j]]
                graph[idx1][idx2] += 1



# Pagerank 계산
A = normalize(graph, axis=0, norm='l1')
R = np.ones((vocab_size, 1))
d = 0.85
bias = (1-d) * np.ones((vocab_size,1))
for _ in range(30):
    R = d * np.dot(A, R) + bias

# 상위 키워드 추출
top_n = 10
idxs = R.flatten().argsort()[-top_n:][::-1]
keywords = [vocab[idx] for idx in idxs]
print(keywords)
# Out:
# ['반도체', '오디오', '메모리', '월렛', '패널', '디스플레이', '스마트폰', '디지털', '모바일', '카메라']

# %%
class TextRankKeywordExtractor:
    def __init__(self, text:str, stopwords:list[str]=None):
        self.text = text

        # define tagger
        tagger = Okt()

        # make vocab list
        if stopwords:
            # get nouns in given text
            nouns = tagger.nouns(self.text)
            # remove stopwords in nouns
            self.vocab = list(set([noun for noun in nouns if noun not in stopwords]))
        else:
            # set raw noun list as vocab list
            self.vocab = tagger.nouns(self.text)
        
        self.vocab_to_idx = {word:idx for idx, word in enumerate(self.vocab)}
        self.vocab_size = len(self.vocab)
    
    def get_coappear_graph(self, window:int):
        self.graph = np.zeros((self.vocab_size, self.vocab_size))
        words = self.text.split()
        for i, word in enumerate(words):
            if word in self.vocab:
                for j in range(max(i-window, 0), min(i+window+1, len(words))):
                    if (i != j) and words[j] in vocab:
                        idx1, idx2 = self.vocab_to_idx[word], self.vocab_to_idx[words[j]]
                        self.graph[idx1][idx2] += 1
    
    def get_pagerank_score(self, d_factor:int, max_iter:int):
        A = normalize(self.graph, axis=0, norm='l1')
        self.R = np.ones((self.vocab_size, 1))
        bias = (1-d_factor) * np.ones((self.vocab_size,1))
        for _ in range(max_iter):
            self.R = d_factor * np.dot(A, self.R) + bias
    
    def get_top_n(self, top_n:int):
        idxs = self.R.flatten().argsort()[-top_n:][::-1]
        return [self.vocab[idx] for idx in idxs]
    
    def extract(self, window:int=5, d_factor:int=0.85, max_iter:int=30, top_n:int=10):
        self.get_coappear_graph(window=window)
        self.get_pagerank_score(d_factor=d_factor, max_iter=max_iter)
        return self.get_top_n(top_n=top_n)

# %%
stopwords = list(set(["종", "그", "및", "등", "각", "개", "를", "사", "위", "전", "용", "처", "통해", "기술", "부문", "경쟁력", "제품", "사업",
             "시장", "판매", "지속", "기업", "생산", "확대", "기업", "당사", "차별", "솔루션", "부품", "개발", "적용", "공정", "한편", "업체",
             "운영", "선두", "전장", "또한", "추진", "구성", "응용", "일반", "영위", "해외", "경영", "본사", "지역", "주요", "다음", "삼성",
             "협업", "서비스", "선단", "특화", "심화", "제품군", "설계", "대형", "세계", "소비자", "라인업", "혁신", "차세대", "공급", "글로벌", "고화질",
             "경쟁", "강화", "더블", "경험", "율", "의", "고하", "뿐", "로서", "탑재", "자체", "원가"]))

textrank_extractor = TextRankKeywordExtractor(text, stopwords=stopwords)

# %%
textrank_extractor.extract(
    window=5,
    max_iter=30
)
# Out:
# ['반도체', '오디오', '메모리', '월렛', '패널', '디스플레이', '스마트폰', '디지털', '모바일', '카메라']

# %%
import pandas as pd

param_grid = {
    "window" : [3,5,7,9],
    "max_iter" : [10, 15, 30]
}
trials = []
col_names = ["window", "max_iter", "keywords"]

for window in param_grid["window"]:
    for max_iter in param_grid["max_iter"]:
        trials.append([
            window, 
            max_iter, 
            textrank_extractor.extract(window=window, max_iter=max_iter, top_n=5)
        ])

pd.DataFrame(trials, columns=col_names).to_csv("./data/textrank_trials.csv", encoding='cp949', index=False)

# %%
pd.read_csv('./data/textrank_trials.csv', encoding='cp949')
# Out:
#     window  max_iter                               keywords
# 0        3        10  ['반도체', '모바일', '오디오', '라이프스타일', '월렛']
# 1        3        15  ['반도체', '모바일', '오디오', '라이프스타일', '월렛']
# 2        3        30  ['반도체', '모바일', '오디오', '라이프스타일', '월렛']
# 3        5        10      ['반도체', '오디오', '메모리', '월렛', '패널']
# 4        5        15      ['반도체', '오디오', '메모리', '월렛', '패널']
# 5        5        30      ['반도체', '오디오', '메모리', '월렛', '패널']
# 6        7        10      ['반도체', '패널', '오디오', '메모리', '고객']
# 7        7        15      ['반도체', '패널', '오디오', '메모리', '고객']
# 8        7        30      ['반도체', '패널', '오디오', '메모리', '고객']
# 9        9        10     ['반도체', '오디오', '메모리', '가전', '카메라']
# 10       9        15      ['반도체', '오디오', '메모리', '대폭', '기본']
# 11       9        30      ['반도체', '오디오', '메모리', '대폭', '기본']

# %% [markdown]
# ---

# %% [markdown]
# ##### `krwordrank` 라이브러리 활용

# %%
from krwordrank.word import KRWordRank

sentences = text.replace("\n", "").split(".")

wordrank_extractor = KRWordRank(
    min_count=1,    # 단어 최소 빈도
    max_length=10,  # 단어 최대 길이
    verbose=True
)

keywords, rank, graph = wordrank_extractor.extract(
    sentences,
    beta=0.85,
    max_iter=30,
)

keywords
# Out:
# scan vocabs ...
# num vocabs = 1416
# done = 19 Early stopped.
# {'있습니다': 16.334569086654728,
#  '사업': 9.36091365621803,
#  '제품': 9.1611851033582,
#  '등을': 8.770329216817776,
#  '통해': 6.626941069579277,
#  '시장': 5.020434357954293,
#  '오디오': 4.74396919212745,
#  'DS(Device': 4.721369658925128,
#  '기술을': 4.638345344395456,
#  'International': 4.595334916488997,
#  '태블릿,': 4.241932490510836,
#  '지속': 4.045472982875407,
#  '반도체': 3.697262162737366,
#  '초대형,': 3.633897497940976,
#  '경쟁력': 3.5710074909024,
#  '있으며,': 3.4812451712426316,
#  '2024년까지': 3.457012288512436,
#  'eXperience),': 3.3952166599261564,
#  'Harman(Harman': 3.145578196926257,
#  '추진': 3.0914566399273555,
#  '당사는': 3.082361496728508,
#  '패널': 3.0371375599518395,
#  'DX(Device': 2.9512071410389367,
#  'NAND': 2.8662101643211293,
#  'AI': 2.852246776742312,
#  '예정입니다': 2.8458274877413867,
#  '부문': 2.7956859083632657,
#  '메모리': 2.7736899988938437,
#  '중소형': 2.754950300668565,
#  '공정에서': 2.7498794964876563,
#  'Dot)': 2.7498780697764715,
#  '한편': 2.6375411112324514,
#  '솔루션': 2.5995444158068604,
#  '원가': 2.558509316553471,
#  '해외': 2.499898847420368,
#  '산하': 2.4941531692154086,
#  '중장기': 2.4315935672261357,
#  'LSI': 2.4142790786756727,
#  '웨어러블(Wearable)제품,': 2.3496483076779295,
#  '따라': 2.2775224527186295,
#  '바탕으로': 2.2511555539499084,
#  '완성차': 2.236047685906359,
#  '생산을': 2.212810421887865,
#  '일반': 2.2075308282564006,
#  'System': 2.207182953681661,
#  '전장부품': 2.1212684089786062,
#  'Solutions)2개의': 2.0017153264184886,
#  '음악': 1.972560096798282,
#  '브랜드를': 1.8981634783093146,
#  '선두': 1.8654517605411272,
#  '응용처를': 1.8336406104155611,
#  '카메라': 1.821150329215885,
#  '또한,': 1.819801994574537,
#  '종속': 1.8130137638038035,
#  '보급형까지': 1.805881073236994,
#  '대한': 1.8043475752088138,
#  'DRAM,': 1.772051684723999,
#  '1위를': 1.7661263754691112,
#  '명성을': 1.755834459181048,
#  '있는': 1.6922577437178288,
#  '나누어': 1.670127422871683,
#  '우위는': 1.6444056215968308,
#  '삶을': 1.6336473670748353,
#  '하는': 1.6177486065957405,
#  '주력제품에': 1.6155846610749136,
#  '구성되어': 1.6112127355909216,
#  '사이에서': 1.6038399562167496,
#  '연속': 1.6005594655541562,
#  '냉장고,': 1.551695330723045,
#  '대폭': 1.5444819939596144,
#  '하여,': 1.5081630342102401,
#  'Mature': 1.4999706982789935,
#  '라인업과': 1.4988672801940872,
#  '[Harman]Harman은': 1.4763567161265292,
#  '커넥티드카': 1.4642197458946744,
#  '차별': 1.4560129667863895,
#  '퀀텀닷(Quantum': 1.4503974507483828,
#  '라이프스타일': 1.4004148232911233,
#  '적용해': 1.3973027540620166,
#  '5개지역총괄의': 1.39530173132541,
#  '세탁기,': 1.379604144937328,
#  '디지털': 1.376719499211716,
#  '19년': 1.3701252475206327,
#  '14년': 1.3701252475206327,
#  'Flash': 1.3592604925089193,
#  '모니터,': 1.3348367561943015,
#  '고객': 1.32547413052616,
#  '전자': 1.318012337800794,
#  '물론이고,': 1.303796792364078,
#  '모바': 1.3037633856770845,
#  '프리미엄부터': 1.2958455693743391,
#  '글로벌': 1.2942947825183757,
#  '협업': 1.2861716608465792,
#  '벌리고': 1.2786988976160352,
#  '스마트폰': 1.276798713199181,
#  '9개': 1.2762644062703425,
#  'SDC,': 1.2506740304238617,
#  '대형': 1.20794210120687,
#  '심화되는': 1.2042059012357544,
#  '[DS': 1.1897591513774537,
#  '가운데,': 1.184437802338285,
#  "'갤럭시(Galaxy)'": 1.1820953602497757,
#  '혁신': 1.1518927711469282,
#  '운영을': 1.1498293325365523,
#  '본사를': 1.1458726082839112,
#  '확대': 1.1411987202913982,
#  'TV': 1.1271246354712943,
#  '쌓아왔습니다': 1.126490378371799,
#  'Foundry': 1.12173984675087,
#  '자리를': 1.1161877519465981,
#  '다음과': 1.0870538639940919,
#  '디스플레이': 1.0843592889129399,
#  '228개의': 1.078194647862829,
#  '상황에': 1.0672008406745048,
#  '성장에': 1.0644835877270868,
#  '애호가들': 1.0390421512598251,
#  'IP': 1.0369732743522067,
#  '소비': 1.0257173376122184,
#  '네트워크시스템': 1.016985276999654,
#  '업체': 1.0029705965709237,
#  '고화질,': 0.997889261216102,
#  '넓혀': 0.9898150642468845,
#  '기본': 0.9754813565981346,
#  'Advanced': 0.9735684622852591,
#  '거점으로': 0.966062845010056,
#  '판매': 0.9557043800391471,
#  '차량용': 0.9547562027458476,
#  'OLED': 0.9537761629946966,
#  '성능의': 0.9338178840962366,
#  '포트폴리오': 0.9212774455737381,
#  '강화': 0.9075775855077067,
#  '[SDC]SDC의': 0.9023146881651563,
#  '출하량': 0.878436783961609,
#  '주요': 0.8772567587699047,
#  '경험을': 0.8747108945127563,
#  '깊은': 0.8720336583162661,
#  '에어컨': 0.8696743948765161,
#  '한국과': 0.8677026466556642,
#  '다양': 0.8608190016121576,
#  '센서칩': 0.8510298667341021,
#  '지배력을': 0.8467234217473635,
#  '자체': 0.8348288210502979,
#  '월렛': 0.8330005207713548,
#  '이해를': 0.8289199576828237,
#  '유지하': 0.8277012385685565,
#  '지키고': 0.8157159761756506,
#  '등으로': 0.8155387040934022,
#  '제공하': 0.8134164108496813,
#  '중심': 0.8129959098689029,
#  '하고': 0.8123709351963172,
#  '영위하': 0.8110520773188422,
#  '고성능': 0.8093827125601523,
#  '확장을': 0.7911695732206578,
#  '개발': 0.7836245900032865,
#  '공급하': 0.7812364692758916,
#  '출시': 0.7796120347163772,
#  '경영을': 0.7785257945231014,
#  '향상을': 0.7784324368931912,
#  '인수': 0.7682917561550001,
#  '제고하': 0.7657527483403609,
#  '가전': 0.7613693321437319,
#  '최적화된': 0.7596811188843173,
#  '특성에': 0.7585916447512818,
#  '나가고': 0.755855374234959,
#  '친환경·고효율': 0.7513530432947035,
#  '분야에서': 0.749293495544632,
#  '중이며': 0.7282444616812872,
#  '협력': 0.7247191160285386,
#  '기업입니다': 0.7148868914097523,
#  '차세대': 0.7119008417417241,
#  '서비스를': 0.7045037160054937,
#  '제조': 0.7010885248320908,
#  '위탁': 0.6976151184364175,
#  '있을': 0.6763317519344433,
#  '질적': 0.6740232142795828,
#  '수요': 0.6596317466525287,
#  '편리': 0.6446267681397619,
#  '아니': 0.628414097070509,
#  '영역을': 0.6261033691953952,
#  '지역': 0.6244518050919102,
#  '점유': 0.6191145495600712,
#  '같습니다': 0.5749120052154777,
#  '프로': 0.5628410026262828,
#  '특화': 0.5536059099888962,
#  '전략': 0.5468404485212667,
#  '선단': 0.5263806881785621,
#  '변화하': 0.525930472844411,
#  '활용하': 0.5118359040262066,
#  '등에': 0.5007145518585001,
#  '탑재': 0.49559921659064876,
#  '설계ᆞ': 0.495444556501024,
#  '세계': 0.46509284330618667,
#  '폴더블ᆞIT(태블릿/노트북)ᆞAuto': 0.3594142736654636}

# %% [markdown]
# #### 1-1-3. Topic Modeling (LDA 등)
#
# - 장점
#     - 트렌드, 주요 주제 파악에 강력한 성능 제공
#     - 여러 기업 보고서 비교 가능
# - 단점
#     - 설정 복잡 (추가 해석이 필요함)
#
# > `gensim`의 `LdaModel` `BERTopic` 등 활용

# %%
from konlpy.tag import Okt
from gensim import corpora
from gensim.models.ldamodel import LdaModel

okt = Okt()

noun_docs = [okt.nouns(text)]

stopwords = list(set(["종", "그", "및", "등", "각", "개", "를", "사", "위", "전", "용", "처", "통해", "기술", "부문", "경쟁력", "제품", "사업",
             "시장", "판매", "지속", "기업", "생산", "확대", "기업", "당사", "차별", "솔루션", "부품", "개발", "적용", "공정", "한편", "업체",
             "운영", "선두", "전장", "또한", "추진", "구성", "응용", "일반", "영위", "해외", "경영", "본사", "지역", "주요", "다음", "삼성",
             "협업", "서비스", "선단", "특화", "심화", "제품군", "설계", "대형", "세계", "소비자", "라인업", "혁신", "차세대", "공급", "글로벌", "고화질",
             "경쟁", "강화", "더블", "경험", "율", "의", "고하", "뿐", "로서", "탑재", "자체", "원가", "연속", "초대형"]))

docs = [[word for word in nouns if word not in stopwords] for nouns in noun_docs]

corp_dict = corpora.Dictionary(docs)
corpus = [corp_dict.doc2bow(doc) for doc in docs]

lda = LdaModel(corpus, num_topics=5, id2word=corp_dict, passes=15)

topics = lda.print_topics(num_words=5)
for idx, topic in topics:
    print(f"Topic #{idx}: {topic}")
# Out:
# Topic #0: 0.010*"반도체" + 0.010*"오디오" + 0.010*"디스플레이" + 0.010*"태블릿" + 0.010*"패널"
# Topic #1: 0.035*"반도체" + 0.028*"패널" + 0.028*"오디오" + 0.022*"태블릿" + 0.022*"메모리"
# Topic #2: 0.010*"패널" + 0.010*"반도체" + 0.010*"오디오" + 0.010*"모바일" + 0.010*"메모리"
# Topic #3: 0.010*"반도체" + 0.010*"오디오" + 0.010*"패널" + 0.010*"메모리" + 0.010*"모바일"
# Topic #4: 0.010*"오디오" + 0.010*"반도체" + 0.010*"패널" + 0.010*"메모리" + 0.010*"디스플레이"

# %% [markdown]
# #### 1-1-4. Embedding Model 기반 키워드 추출
#
# > 문서 전체 임베딩과 단어 또는 구절의 임베딩 벡터 유사도를 비교해 중요한 키워드 선정
#
# - 장점
#     - 문맥을 반영한 정밀한 키워드 추출
# - 단점
#     - 사전학습 임베딩 모델 필요, 속도 느릴 수 있음

# %%
from konlpy.tag import Okt
from langchain_openai.embeddings import OpenAIEmbeddings
from dotenv import load_dotenv
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

okt = Okt()

nouns = okt.nouns(text)

stopwords = list(set(["종", "그", "및", "등", "각", "개", "를", "사", "위", "전", "용", "처", "통해", "기술", "부문", "경쟁력", "제품", "사업",
             "시장", "판매", "지속", "기업", "생산", "확대", "기업", "당사", "차별", "솔루션", "부품", "개발", "적용", "공정", "한편", "업체",
             "운영", "선두", "전장", "또한", "추진", "구성", "응용", "일반", "영위", "해외", "경영", "본사", "지역", "주요", "다음", "삼성",
             "협업", "서비스", "선단", "특화", "심화", "제품군", "설계", "대형", "세계", "소비자", "라인업", "혁신", "차세대", "공급", "글로벌", "고화질",
             "경쟁", "강화", "더블", "경험"]))

candidates = list(set([noun for noun in nouns if noun not in stopwords]))


load_dotenv()
embedding_model = OpenAIEmbeddings()

embedding_vectors = embedding_model.embed_documents(candidates)
whole_text_embedding_vector = embedding_model.embed_query(text)

cos_sim_score = []

for embedding_vector in embedding_vectors:
    cos_sim_score.append(cosine_similarity([embedding_vector], [whole_text_embedding_vector])[0][0])

cos_sim_score_df = pd.DataFrame([cos_sim_score], columns=candidates)

def get_top_words(row:pd.Series, top_n:int=7):
    return row.sort_values(ascending=False).head(top_n).index.tolist()

print(cos_sim_score_df.apply(get_top_words, axis=1))
# Out:
# 0    [디스플레이, 디지털, 스마트폰, 모바일, 갤럭시, 퀀텀닷, 커넥티드카]
# dtype: object

# %% [markdown]
# #### 1-1-5. LLM 기반 요약/키워드 추출
#
# > LLM 모델을 활용, 프롬프트를 통해 키워드 추출 요청
#
# - 장점
#     - 의미론 기반 고차원 추출
#     - 인간 수준의 결과 제공
# - 단점
#     - 비용
#     - 일관성 확보
#     - 선정 과정 설명 불가능

# %%
from typing_extensions import TypedDict
from typing import Annotated
from langchain_core.messages import (
    HumanMessage,
    SystemMessage
)
from langchain_openai import ChatOpenAI
from pydantic import BaseModel
from langgraph.graph import StateGraph, START, END

class KeyWordsModel(BaseModel):
    keywords: Annotated[list[str], "텍스트로 부터 추출한 키워드를 담는 리스트"]

llm = ChatOpenAI(
    model='gpt-4o',
    temperature=0
)
structured_llm = llm.with_structured_output(KeyWordsModel)

# Define State
class InputState(TypedDict):
    context: str

class OutputState(TypedDict):
    keywords: list[str]

class GraphState(InputState, OutputState):
    pass

# Define Nodes
def keyword_extraction_node(state: InputState):
    context = state['context']

    system_message_content = """
    당신은 전문적인 기업 트렌드 분석가 입니다.
    당신의 임무는 주어진 텍스트에서 기업 분석을 위한 주요 키워드를 추출하는 것입니다.
    다음의 지침을 준수하며 기업의 트렌드 분석이 가능하도록 키워드를 10개 추출하세요.

    <지침>
    1. '사업', '선두주자'와 같이 해당 기업에 대해 설명할 수 없는 너무 일반적인 키워드는 제외하세요.
    2. '~부문' 과 같이 특정 분야를 총괄하는 키워드는 제외하고, 기업에 대해 분석 가능한 직접적인 키워드를 선정하세요.
    </지침>
    """

    human_message_content = f"""
    다음의 텍스트에서 해당 기업의 트렌드 분석을 위한 키워드를 추출해주세요.

    텍스트:
    {context}
    """

    system_message = SystemMessage(content=system_message_content)
    human_message = HumanMessage(content=human_message_content)

    keyword_list = structured_llm.invoke([system_message, human_message])

    return {
        "keywords" : keyword_list.keywords
    }


# Define Graph Builder
workflow = StateGraph(
    GraphState,
    input=InputState,
    output=OutputState
)

# add nodes
workflow.add_node("extract_keywords", keyword_extraction_node)

# add edges
workflow.add_edge(START, "extract_keywords")
workflow.add_edge("extract_keywords", END)

# Compile Graph
app = workflow.compile()

app

# %%
app.invoke({"context" : text})
# Out:
# {'keywords': ['DX(Device eXperience)',
#   '삼성디스플레이(SDC)',
#   'Harman International Industries',
#   'TV사업',
#   'AI신기술',
#   '갤럭시(Galaxy) 브랜드',
#   '메모리 반도체',
#   'System LSI',
#   'Foundry 사업',
#   'OLED 패널']}

# %% [markdown]
# ### 1-2. 키워드 선정

# %% [markdown]
# ## 2. 뉴스 모니터링
